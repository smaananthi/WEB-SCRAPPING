# %% [markdown]
# # **Wikipedia library**

# %%
# !pip install wikipedia

# %%
import wikipedia as wk

# %%
print(wk.search("History of India"))
# Out:
# ['History of India', 'Economic history of India', 'History of tea in India', 'Military history of India', 'Demographics of India', 'History of India (1947–present)', 'Linguistic history of India', 'History of Buddhism in India', 'Timeline of Indian history', 'India']

# %%
print(wk.search("History of India (1947–present)",results=5))
# Out:
# ['History of India (1947–present)', 'History of Pakistan (1947–present)', 'Flag of India', 'Partition of India', 'Culture of India']

# %%
print(wk.summary("History of India (1947–present)"))
# Out:
# The history of independent India or history of Republic of India began when the country became an independent sovereign state within the British Commonwealth on 15 August 1947. Direct administration by the British, which began in 1858, affected a political and economic unification of the subcontinent. When British rule came to an end in 1947, the subcontinent was partitioned along religious lines into two separate countries—India, with a majority of Hindus, and Pakistan, with a majority of Muslims. Concurrently the Muslim-majority northwest and east of British India was separated into the Dominion of Pakistan, by the Partition of India. The partition led to a population transfer of more than 10 million people between India and Pakistan and the death of about one million people. Indian National Congress leader Jawaharlal Nehru became the first Prime Minister of India, but the leader most associated with the independence struggle, Mahatma Gandhi, accepted no office. The constitution ad
# ...

# %%
full_page = wk.page("History of India (1947–present)")

# %%
print(full_page.content) #If we only use "full_page.content" then we dont get this kind of proper output. we only get all data in a para format
# Out:
# The history of independent India or history of Republic of India began when the country became an independent sovereign state within the British Commonwealth on 15 August 1947. Direct administration by the British, which began in 1858, affected a political and economic unification of the subcontinent. When British rule came to an end in 1947, the subcontinent was partitioned along religious lines into two separate countries—India, with a majority of Hindus, and Pakistan, with a majority of Muslims. Concurrently the Muslim-majority northwest and east of British India was separated into the Dominion of Pakistan, by the Partition of India. The partition led to a population transfer of more than 10 million people between India and Pakistan and the death of about one million people. Indian National Congress leader Jawaharlal Nehru became the first Prime Minister of India, but the leader most associated with the independence struggle, Mahatma Gandhi, accepted no office. The constitution ad
# ...

# %%
print(full_page.url)
# Out:
# https://en.wikipedia.org/wiki/History_of_India_(1947%E2%80%93present)

# %%
print(full_page.title)
# Out:
# History of India (1947–present)

# %%
full_page.references
# Out:
# ['http://edition.cnn.com/2008/WORLD/asiapcf/05/13/india.bombs/index.html',
#  'http://news.bbc.co.uk/2/hi/6910097.stm',
#  'http://www.outlookindia.com/article.aspx?266145',
#  'http://www.satp.org/satporgtp/countries/india/index.html',
#  'http://www.newsweek.com/id/47261',
#  'http://encarta.msn.com/encyclopedia_761560851_9/Pakistan.html',
#  'http://www.thehindu.com/business/Industry/more-saradha-entities-under-sebi-scanner/article4650522.ece',
#  'http://www.thehindu.com/opinion/editorial/cheat-funds-again/article4654467.ece',
#  'http://www.livemint.com/Specials/TQWJ1auPZMCYnZqC4tK7VN/Saradha-raised-deposits-from-17-million-people-probe-finds.html',
#  'http://www.firstpost.com/india/ibn7-journalist-killed-in-up-communal-riots-army-clamps-curfew-1092877.html',
#  'http://www.indianexpress.com/news/9-killed-in-communal-riots-in-muzaffarnagar-curfew-clamped-army-deployed/1166053/',
# ...

# %%
full_page.images
# Out:
# ['https://upload.wikimedia.org/wikipedia/commons/3/34/1965_war.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/1/16/1971_Instrument_of_Surrender.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/8/87/Ab_vajpayee.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/96/Agni-II_missile_%28Republic_Day_Parade_2004%29.jpeg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/c4/Akal_Takht_and_Harmandir_Sahib%2C_Amritsar%2C_Punjab%2C_India.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/c3/Amul_Plant_at_Anand.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/f/f9/Assam_in_1950s.png',
#  'https://upload.wikimedia.org/wikipedia/commons/a/a4/BHOPAL_%28231583728%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/d/d7/Bundesarchiv_Bild_183-61849-0001%2C_Indien%2C_Otto_Grotewohl_bei_Ministerpr%C3%A4sident_Nehru_cropped.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/6/6a/Bush_%26_Singh_in_New_Delhi.jpg',
# ...

# %%
full_page.links
# Out:
# ['14th Dalai Lama',
#  '1915 Singapore Mutiny',
#  '1946 Cabinet Mission to India',
#  '1951–52 Indian general election',
#  '1962 Indian general election',
#  '1962 Madras Legislative Assembly election',
#  '1962 Sino-Indian War',
#  '1971 Bangladesh genocide',
#  '1973 oil crisis',
#  '1974 railway strike in India',
#  '1975 Sikkimese monarchy referendum',
#  '1984 anti-Sikh riots',
#  '1990s in India',
#  '1991 Indian economic crisis',
#  '1997 Asian financial crisis',
#  '2001 Gujarat earthquake',
#  '2001 Indian Parliament attack',
#  '2001–02 India–Pakistan standoff',
#  '2002 Gujarat riots',
#  '2004 Indian Ocean earthquake and tsunami',
#  '2004 Indian general election',
#  '2005 Kashmir earthquake',
#  '2008 Lok Sabha vote of confidence',
#  '2008 Mumbai attacks',
#  '2009 Indian general election',
#  '2010 Commonwealth Games',
#  '2010 Ladakh floods',
#  '2011 Indian anti-corruption movement',
#  '2012 Delhi gang rape and murder',
#  '2013 Muzaffarnagar riots',
# ...

# %%
full_page.categories #explore the hierarchical structure of categories associated with the Wikipedia page, providing additional context about the content and topics covered in the page.
# Out:
# ['All Wikipedia articles written in Indian English',
#  'All articles lacking reliable references',
#  'All articles needing additional references',
#  'All articles with dead external links',
#  'All articles with unsourced statements',
#  'Articles lacking reliable references from May 2023',
#  'Articles needing additional references from January 2021',
#  'Articles using infobox templates with no data rows',
#  'Articles with dead external links from October 2023',
#  'Articles with permanently dead external links',
#  'Articles with short description',
#  'Articles with unsourced statements from June 2023',
#  'Articles with unsourced statements from May 2023',
#  'History of India',
#  'History of the Republic of India',
#  'Short description is different from Wikidata',
#  'Use Indian English from December 2019',
#  'Use dmy dates from January 2023',
#  'Webarchive template wayback links',
#  'Wikipedia articles needing page number citations from November 2022']

# %%
html = wk.page("History of India (1947–present)").html().encode("UTF-8")

import pandas as pd
df = pd.read_html(html)[5]   #specifically selecting the 6th table
df
# Out:
#                                                      0                 1
# 0    Palaeolithic (2,500,000â250,000 BC) Madrasia...               NaN
# 1                                    Madrasian culture               NaN
# 2                                      Soanian culture               NaN
# 3    Neolithic (10,800â3300 BC) Bhirrana culture ...               NaN
# 4                                     Bhirrana culture  (7570â6200 BC)
# ..                                                 ...               ...
# 140                                        Dutch India     (1605â1825)
# 141                                       Danish India     (1620â1869)
# 142                                       French India     (1759â1954)
# 143                                        Company Raj     (1757â1858)
# 144                                        British Raj     (1858â1947)
#
# [145 rows x 2 columns]

# %%
df.columns
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
df.head()
# Out:
#                                                    0                 1
# 0  Palaeolithic (2,500,000â250,000 BC) Madrasia...               NaN
# 1                                  Madrasian culture               NaN
# 2                                    Soanian culture               NaN
# 3  Neolithic (10,800â3300 BC) Bhirrana culture ...               NaN
# 4                                   Bhirrana culture  (7570â6200 BC)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       145 non-null    object
#  1   1       134 non-null    object
# dtypes: object(2)
# memory usage: 2.4+ KB

# %%
df=pd.DataFrame(df)

# %%
new_column_names = ['Culture', 'Year']
df = df.rename(columns=dict(zip(df.columns, new_column_names)))
df
# Out:
#                                                Culture              Year
# 0    Palaeolithic (2,500,000â250,000 BC) Madrasia...               NaN
# 1                                    Madrasian culture               NaN
# 2                                      Soanian culture               NaN
# 3    Neolithic (10,800â3300 BC) Bhirrana culture ...               NaN
# 4                                     Bhirrana culture  (7570â6200 BC)
# ..                                                 ...               ...
# 140                                        Dutch India     (1605â1825)
# 141                                       Danish India     (1620â1869)
# 142                                       French India     (1759â1954)
# 143                                        Company Raj     (1757â1858)
# 144                                        British Raj     (1858â1947)
#
# [145 rows x 2 columns]
