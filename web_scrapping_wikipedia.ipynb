# %% [markdown]
# # HTML - WEB SCRAPPING

# %% [markdown]
# ## **USING BEAUTIFULSOUP**

# %%
#Import required library
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
# open and read the url
url = urlopen("https://en.wikipedia.org/wiki/India")
df = BeautifulSoup(url.read(),'html.parser')
df
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-night-mode-clientpref-0 vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>India - Wikipedia</title>
# ...

# %% [markdown]
# #### finding header and title

# %%
#get title
df.title
# Out:
# <title>India - Wikipedia</title>

# %%
#get header1
df.h1
# Out:
# <h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-main">India</span></h1>

# %%
# finding all header
df.find_all('h2')
# Out:
# [<h2 class="vector-pinnable-header-label">Contents</h2>,
#  <h2><span class="mw-headline" id="Etymology">Etymology</span></h2>,
#  <h2><span class="mw-headline" id="History">History</span></h2>,
#  <h2><span class="mw-headline" id="Geography">Geography</span></h2>,
#  <h2><span class="mw-headline" id="Biodiversity">Biodiversity</span></h2>,
#  <h2><span class="mw-headline" id="Politics_and_government">Politics and government</span></h2>,
#  <h2><span id="Foreign.2C_economic_and_strategic_relations"></span><span class="mw-headline" id="Foreign,_economic_and_strategic_relations">Foreign, economic and strategic relations</span></h2>,
#  <h2><span class="mw-headline" id="Economy">Economy</span></h2>,
#  <h2><span id="Demographics.2C_languages_and_religion"></span><span class="mw-headline" id="Demographics,_languages_and_religion">Demographics, languages and religion</span></h2>,
#  <h2><span class="mw-headline" id="Culture">Culture</span></h2>,
# ...

# %% [markdown]
# ####finding anchor_tag

# %%
#first_anchor_tag
df.a
# Out:
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>

# %%
#using find_all anchor_tag
anchor_tag=df.find_all('a')
len(anchor_tag)
# Out:
# 5682

# %%
anchor_tag[567]
# Out:
# <a class="mw-redirect" href="/wiki/Indo-European_language" title="Indo-European language">Indo-European language</a>

# %%
for anchor_tag in anchor_tag:
  href_attribute = anchor_tag.get('href')
  print(href_attribute)
# Out:
# Streaming output truncated to the last 5000 lines.
# /wiki/Achaemenid_Empire
# /wiki/Cognate
# /wiki/Sanskrit
# /wiki/Indus_River
# #cite_note-86
# #cite_note-FOOTNOTEThieme1970447–450-87
# /wiki/Ancient_Greece
# https://www.loc.gov/standards/iso639-2/php/langcodes_name.php?code_ID=
# #cite_note-FOOTNOTEKuiper201086-88
# /wiki/Names_for_India#Bhārata
# /wiki/Help:IPA/Hindi_and_Urdu
# //upload.wikimedia.org/wikipedia/commons/transcoded/7/79/Hi-Bharat.ogg/Hi-Bharat.ogg.mp3
# /wiki/File:Hi-Bharat.ogg
# /wiki/Indian_epic_poetry
# /wiki/Constitution_of_India
# #cite_note-FOOTNOTEClémentin-Ojha2014-89
# #cite_note-90
# /wiki/Names_of_India_in_its_official_languages
# /wiki/North_India
# #cite_note-Jha2014-91
# #cite_note-FOOTNOTESingh2017[httpsbooksgooglecombooksiddYM4DwAAQBAJpgPA253_253]-92
# #cite_note-FOOTNOTEClémentin-Ojha2014-89
# #cite_note-FOOTNOTEBarrow2003-93
# /wiki/Hindustan
# /wiki/Help:IPA/Hindi_and_Urdu
# ...

# %% [markdown]
# #### finding line breaks

# %%
line_breaks = df.find_all('br')
len('line_breaks')
# Out:
# 11

# %% [markdown]
# ####finding para

# %%
#finding para
para = df.find_all('p')
len(para)   #totally we have 102 paras in this url
# Out:
# 104

# %%
para[55]
# Out:
# <p>Despite economic growth during recent decades, India continues to face socio-economic challenges. In 2006, India contained the <a href="/wiki/Poverty_in_India" title="Poverty in India">largest number</a> of people living below the World Bank's international poverty line of US$1.25 per day.<sup class="reference" id="cite_ref-365"><a href="#cite_note-365">[349]</a></sup> The proportion decreased from 60% in 1981 to 42% in 2005.<sup class="reference" id="cite_ref-366"><a href="#cite_note-366">[350]</a></sup> Under the World Bank's later revised poverty line, it was 21% in 2011.<sup class="reference" id="cite_ref-368"><a href="#cite_note-368">[q]</a></sup><sup class="reference" id="cite_ref-WB2015_369-0"><a href="#cite_note-WB2015-369">[352]</a></sup> 30.7% of India's children under the age of five are underweight.<sup class="reference" id="cite_ref-370"><a href="#cite_note-370">[353]</a></sup> According to a <a href="/wiki/Food_and_Agriculture_Organization" title="Food and Agricultur
# ...

# %% [markdown]
# #### finding all images

# %%
#finding all images
df.find_all('img')
# Out:
# [<img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>,
#  <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>,
#  <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>,
#  <img alt="Featured article" class="mw-file-element" data-file-height="443" data-file-width="466" decoding="async" height="19" src="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/30px-Cscr-featured.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/40px-Cscr-featured.svg.png 2x" width="20"/>,
# ...

# %%
#length of images
img= df.find_all('img')
len(img)
# Out:
# 133

# %%
img[0]
# Out:
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>

# %% [markdown]
# #### finding bold(< strong>) and Italic (< em>) character
#
# Remove space inside tag 'strong' and 'em'. I only used it in order to display the format of the tag

# %%
bold_char = df.find_all('b')
bold_char
# Out:
# [<b>Motto: </b>,
#  <b>Anthem:</b>,
#  <b>National song: <style data-mw-deduplicate="TemplateStyles:r886047488">.mw-parser-output .nobold{font-weight:normal}</style><span class="nobold"><span title="Sanskrit-language text"><span lang="sa" style="font-style: normal;">"<a href="/wiki/Vande_Mataram" title="Vande Mataram">Vande Mataram</a>"</span></span> <span class="languageicon" style="font-size:100%; font-weight:normal">(<a class="mw-redirect" href="/wiki/Sanskrit_language" title="Sanskrit language">Sanskrit</a>)</span><sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[c]</a></sup></span></b>,
#  <b>India</b>,
#  <b>Republic of India</b>,
#  <b><a href="#cite_ref-2">^</a></b>,
#  <b><a href="#cite_ref-7">^</a></b>,
#  <b><a href="#cite_ref-8">^</a></b>,
#  <b><a href="#cite_ref-11">^</a></b>,
#  <b><a href="#cite_ref-15">^</a></b>,
#  <b><a href="#cite_ref-16">^</a></b>,
#  <b><a href="#cite_ref-19">^</a></b>,
#  <b><a href="#cite_ref-22">^</a></b>,
# ...

# %%
italic =df.find_all('i')
italic
# Out:
# [<i lang="hi-Latn">Bhārat Gaṇarājya</i>,
#  <i><a href="/wiki/Daylight_saving_time" title="Daylight saving time">DST</a> is not observed.</i>,
#  <i lang="hi-Latn">Bhārat Gaṇarājya</i>,
#  <i><a href="/wiki/Rigveda" title="Rigveda">Rigveda</a></i>,
#  <i>Rigveda</i>,
#  <i><a href="/wiki/Oxford_English_Dictionary" title="Oxford English Dictionary">Oxford English Dictionary</a></i>,
#  <i>India</i>,
#  <i>India</i>,
#  <i> Ἰνδία</i>,
#  <i>Indos</i>,
#  <i> Ἰνδός</i>,
#  <i><a href="/wiki/Hindush" title="Hindush">Hindush</a></i>,
#  <i>Sindhu</i>,
#  <i>Indoi</i>,
#  <i><span class="plainlinks"><a class="external text" href="https://www.loc.gov/standards/iso639-2/php/langcodes_name.php?code_ID=" rel="nofollow">Ἰνδοί</a></span></i>,
#  <i><a href="/wiki/Names_for_India#Bhārata" title="Names for India">Bharat</a></i>,
#  <i lang="hi-Latn">Bhārat</i>,
#  <i>Bharatavarsha</i>,
#  <i>Bharat</i>,
#  <i><a href="/wiki/Hindustan" title="Hindustan">Hindustan</a></i>,
#  <i>Hindustan</i>,
# ...

# %% [markdown]
# #### unordered(bulleted)list

# %%
unordered_list = df.find_all('ul')
len(unordered_list)
# Out:
# 226

# %%
unordered_list[200] #need to work
# Out:
# <ul><li><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/23px-Flag_of_Algeria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/35px-Flag_of_Algeria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/45px-Flag_of_Algeria.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/Algeria" title="Algeria">Algeria</a></li>
# ...

# %%
unordered_list_200 = unordered_list[200]
list_unorder_200 = unordered_list_200.find_all('li')
list_content_200 =[li.get_text() for li in list_unorder_200]
list_content_200
# Out:
# ['\xa0Algeria',
#  '\xa0Bangladesh',
#  '\xa0East Timor',
#  '\xa0Iraq',
#  '\xa0Israel',
#  '\xa0Syria']

# %% [markdown]
# #### ordered(numbered)list

# %%
ordered_list = df.find_all('ol')
len(ordered_list)
# Out:
# 5

# %%
for ol in ordered_list:
  list = ol.find_all('li')
  for li in list:
    print(li.get_text())
# Out:
# Andhra Pradesh
# Arunachal Pradesh
# Assam
# Bihar
# Chhattisgarh
# Goa
# Gujarat
# Haryana
# Himachal Pradesh
# Jharkhand
# Karnataka
# Kerala
# Madhya Pradesh
# Maharashtra
# Manipur
# Meghalaya
# Mizoram
# Nagaland
# Odisha
# Punjab
# Rajasthan
# Sikkim
# Tamil Nadu
# Telangana
# Tripura
# Uttar Pradesh
# Uttarakhand
# West Bengal
# Andaman and Nicobar Islands
# Chandigarh
# Dadra and Nagar Haveli and Daman and Diu
# Jammu and Kashmir
# Ladakh
# Lakshadweep
# National Capital Territory of Delhi
# Puducherry
# ^ Originally written in Sanskritised Bengali and adopted as the national anthem in its Hindi translation
#
# ^ "[...] Jana Gana Mana is the National Anthem of India, subject to such alterations in the words as the Government may authorise as occasion arises; and the song Vande Mataram, which has played a historic part in the struggle for Indian freedom, shall be honoured equally with Jana Gana Mana and shall have equal status with it."[5]
#
# ...

# %%
ordered_list_0= ordered_list[0]
ordered_list_0
# Out:
# <ol><li><a href="/wiki/Andhra_Pradesh" title="Andhra Pradesh">Andhra Pradesh</a></li>
# <li><a href="/wiki/Arunachal_Pradesh" title="Arunachal Pradesh">Arunachal Pradesh</a></li>
# <li><a href="/wiki/Assam" title="Assam">Assam</a></li>
# <li><a href="/wiki/Bihar" title="Bihar">Bihar</a></li>
# <li><a href="/wiki/Chhattisgarh" title="Chhattisgarh">Chhattisgarh</a></li>
# <li><a href="/wiki/Goa" title="Goa">Goa</a></li>
# <li><a href="/wiki/Gujarat" title="Gujarat">Gujarat</a></li>
# <li><a href="/wiki/Haryana" title="Haryana">Haryana</a></li>
# <li><a href="/wiki/Himachal_Pradesh" title="Himachal Pradesh">Himachal Pradesh</a></li>
# <li><a href="/wiki/Jharkhand" title="Jharkhand">Jharkhand</a></li>
# <li><a href="/wiki/Karnataka" title="Karnataka">Karnataka</a></li>
# <li><a href="/wiki/Kerala" title="Kerala">Kerala</a></li>
# <li><a href="/wiki/Madhya_Pradesh" title="Madhya Pradesh">Madhya Pradesh</a></li>
# <li><a href="/wiki/Maharashtra" title="Maharashtra">Maharashtra</a></li>
# ...

# %%
lists_0 = ordered_list_0.find_all('li')
list_content_0 =[li.get_text() for li in lists_0]
list_content_0
# Out:
# ['Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal']

# %%
ordered_list_1= ordered_list[1]
lists_1 = ordered_list_1.find_all('li')
list_content_1 =[li.get_text() for li in lists_1]
list_content_1
# Out:
# ['Andaman and Nicobar Islands',
#  'Chandigarh',
#  'Dadra and Nagar Haveli and Daman and Diu',
#  'Jammu and Kashmir',
#  'Ladakh',
#  'Lakshadweep',
#  'National Capital Territory of Delhi',
#  'Puducherry']

# %%
ordered_list_2= ordered_list[2]
lists_2 = ordered_list_2.find_all('li')
list_content_2 =[li.get_text() for li in lists_2]
list_content_2
# Out:
# ['^ Originally written in Sanskritised Bengali and adopted as the national anthem in its Hindi translation\n',
#  '^ "[...] Jana Gana Mana is the National Anthem of India, subject to such alterations in the words as the Government may authorise as occasion arises; and the song Vande Mataram, which has played a historic part in the struggle for Indian freedom, shall be honoured equally with Jana Gana Mana and shall have equal status with it."[5]\n',
#  '^ Written in a mixture of Sanskrit and Sanskritised Bengali\n',
#  '^ According to Part XVII of the Constitution of India, Hindi in the Devanagari script is the official language of the Union, along with English as an additional official language.[1][6][7] States and union territories can have a different official language of their own other than Hindi or English.\n',
# ...

# %% [markdown]
# ####finding all tables

# %%
#finding all tables
table=df.find_all('table')
len(table)
# Out:
# 29

# %%
df.find_all('table')[0].find_all('tr')
# Out:
# [<tr><th class="infobox-above adr" colspan="2"><div class="fn org country-name">Republic of India</div><div class="ib-country-names"><span title="ISO 15919 Indic (Hindi language) transliteration"><i lang="hi-Latn">Bhārat Gaṇarājya</i></span><br/><span style="font-size:85%;">(see <a href="/wiki/Names_of_India_in_its_official_languages" title="Names of India in its official languages">other regional names</a>)</span></div></th></tr>,
#  <tr><td class="infobox-image" colspan="2"><div class="noresize" style="display:table; width:100%;">
#  <div style="display:table-cell; vertical-align:middle; padding-left:5px;">
# ...

# %%
len(df.find_all('table')[0].find_all('tr'))
# Out:
# 52

# %%
df.find_all('table')[0].find_all('tr')[0]
# Out:
# <tr><th class="infobox-above adr" colspan="2"><div class="fn org country-name">Republic of India</div><div class="ib-country-names"><span title="ISO 15919 Indic (Hindi language) transliteration"><i lang="hi-Latn">Bhārat Gaṇarājya</i></span><br/><span style="font-size:85%;">(see <a href="/wiki/Names_of_India_in_its_official_languages" title="Names of India in its official languages">other regional names</a>)</span></div></th></tr>

# %%
df.find_all('table')[0].find_all('tr')[0].get_text()
# Out:
# 'Republic of IndiaBhārat Gaṇarājya(see other regional names)'

# %% [markdown]
# ##### - exploring one of the TABLE

# %%
rows = df.find('table', class_='infobox ib-region-symbols').find_all('tr')
rows
# by mentioning a class you can get a view of a specific table
# Out:
# [<tr class="mergedrow"><th class="infobox-label" scope="row">Emblem</th><td class="infobox-data"><a href="/wiki/State_Emblem_of_India" title="State Emblem of India">Sarnath Lion Capital</a></td></tr>,
#  <tr class="mergedrow"><th class="infobox-label" scope="row">Anthem</th><td class="infobox-data"><i><a href="/wiki/Jana_Gana_Mana" title="Jana Gana Mana">Jana Gana Mana</a></i></td></tr>,
#  <tr class="mergedrow"><th class="infobox-label" scope="row">Song</th><td class="infobox-data">"<a href="/wiki/Vande_Mataram" title="Vande Mataram">Vande Mataram</a>"</td></tr>,
# ...

# %%
#extract text from rows
for i in rows:
  header= i.find('th',class_="infobox-label")
  data = i.find('td',class_="infobox-data")

  if header and data:
    print(header.get_text(strip=True), ':', data.get_text(strip=True))
    # strip=True ===> used to ensure that the extracted text is cleaner
    # and doesn't contain unnecessary whitespace.
    # try to remove "strip=True" and run the code
    # you can see unwanted text in output
# Out:
# Emblem : Sarnath Lion Capital
# Anthem : Jana Gana Mana
# Song : "Vande Mataram"
# Language : None[249][250][251]
# Currency : ₹(Indian rupee)
# Calendar : Shaka
# Bird : Indian peafowl
# Flower : Lotus
# Fruit : Mango
# Mammal : Bengal tigerRiver dolphin
# Tree : Banyan
# River : Ganges
